# %%
import os
import sys
import pandas as pd

sys.path.append('../Scripts')
from Change_Point_Analysis import ChangePointAnalysis
# Out:
# WARNING (pytensor.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# WARNING (pytensor.configdefaults): g++ not detected!  PyTensor will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set PyTensor flags cxx to an empty string.
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 # Ensure this is the correct import for your class

# Create an instance of ChangePointAnalysis
cpa = ChangePointAnalysis()

# Load your data from a CSV file
cpa.load_data('../Data/Copy of BrentOilPrices.csv')  # Replace with your actual file path

# Perform change point detection
cpa.detect_cusum()         # Detect change points using CUSUM
# Out:
# 2024-11-05 08:59:21,162 - INFO - Loading data from ../Data/Copy of BrentOilPrices.csv
# d:\10 ACADAMY KIFIYA\Week 10\Event-Driven-Brent-Oil-Analysis\Notebooks\../Scripts\Change_Point_Analysis.py:25: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   self.data = pd.read_csv(csv_file, parse_dates=['Date'])
# 2024-11-05 08:59:21,508 - INFO - Data loaded successfully.
# 2024-11-05 08:59:21,510 - INFO - Starting CUSUM change point detection.
# 2024-11-05 08:59:21,511 - INFO - CUSUM detected change points at indices: []

# %%
cpa.detect_ruptures()      # Detect change points using ruptures package
# Out:
# 2024-11-05 08:59:21,684 - INFO - Starting ruptures change point detection.
# 2024-11-05 09:00:34,243 - INFO - Ruptures method detected change points at indices: [3160, 4310, 4600, 5170, 5290, 5440, 5600, 5995, 6925, 6985, 7155, 7700, 8330, 8385, 8560, 8800, 9011]

# %%
# Plot all results
cpa.plot_results()         # Visualize the detected change points

# %%
cpa.get_change_point_dates()
# Out:
# 2024-11-05 09:00:34,948 - INFO - Change points detected by CUSUM: []
# 2024-11-05 09:00:34,950 - INFO - Change points detected by Ruptures: [Timestamp('1999-11-02 00:00:00'), Timestamp('2004-05-04 00:00:00'), Timestamp('2005-06-16 00:00:00'), Timestamp('2007-09-12 00:00:00'), Timestamp('2008-03-06 00:00:00'), Timestamp('2008-10-08 00:00:00'), Timestamp('2009-05-29 00:00:00'), Timestamp('2010-12-21 00:00:00'), Timestamp('2014-09-08 00:00:00'), Timestamp('2014-12-02 00:00:00'), Timestamp('2015-08-04 00:00:00'), Timestamp('2017-09-19 00:00:00'), Timestamp('2020-03-09 00:00:00'), Timestamp('2020-05-29 00:00:00'), Timestamp('2021-02-03 00:00:00'), Timestamp('2022-01-14 00:00:00')]
# Change points detected by CUSUM: []
# ...
