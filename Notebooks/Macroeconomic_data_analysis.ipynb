# %%
import os
import sys
import pandas as pd

sys.path.append('../Scripts')
#from Timeseries_model import VARModel
from Macroeconomic_data_analysis import EconomicDataProcessor

# %%
if __name__ == "__main__":
    processor = EconomicDataProcessor('../Data/macroeconomic .csv', '../Data/Exchange rate.csv', '../Data/Copy of BrentOilPrices.csv')
    processor.load_macro_data()

# %%
processor.load_exchange_data()

# %%
processor.merge_data()
# Out:
# d:\10 ACADAMY KIFIYA\Week 10\Event-Driven-Brent-Oil-Analysis\Notebooks\../Scripts\Macroeconomic_data_analysis.py:65: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   brent_df['Date'] = pd.to_datetime(brent_df['Date'])

# %%
processor.visualize_data()
# Out:
# Columns in final_merged_df: ['Date', 'Inflation', 'GDP', 'Unemployment', 'USD to UK', 'USD to Euro', 'USD to Canada', 'Price']
# Data in final_merged_df:
#          Date  Inflation  GDP  Unemployment  USD to UK  USD to Euro  \
# 0 1987-05-20        5.7  3.7           NaN   0.599826     0.913321
# 1 1987-05-21        5.7  3.7           NaN   0.599826     0.913321
# 2 1987-05-22        5.7  3.7           NaN   0.599826     0.913321
# 3 1987-05-25        5.7  3.7           NaN   0.599826     0.913321
# 4 1987-05-26        5.7  3.7           NaN   0.599826     0.913321
#
#    USD to Canada  Price
# 0        1.34148  18.63
# 1        1.34148  18.45
# 2        1.34148  18.55
# 3        1.34148  18.60
# 4        1.34148  18.63

# %%
processor.display_data()
# Out:
#         Date  Inflation  GDP  Unemployment  USD to UK  USD to Euro  \
# 0 1987-05-20        5.7  3.7           NaN   0.599826     0.913321
# 1 1987-05-21        5.7  3.7           NaN   0.599826     0.913321
# 2 1987-05-22        5.7  3.7           NaN   0.599826     0.913321
# 3 1987-05-25        5.7  3.7           NaN   0.599826     0.913321
# 4 1987-05-26        5.7  3.7           NaN   0.599826     0.913321
#
#    USD to Canada  Price
# 0        1.34148  18.63
# 1        1.34148  18.45
# 2        1.34148  18.55
# 3        1.34148  18.60
# 4        1.34148  18.63
